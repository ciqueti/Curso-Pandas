# %% [markdown]
# # Curso Pandas - Exercícios

# %% [markdown]
# ## Informações de um DataFrame

# %%
import pandas as pd
data = [['Fulano',12,7.0,True], ['Sicrano',15,3.5,False],['Beltrano',18,9.3,True]]
dados = pd.DataFrame(data, columns = ['Nome','Idade','Nota','Situação'])
dados
# Out:
#        Nome  Idade  Nota  Situação
# 0    Fulano     12   7.0      True
# 1   Sicrano     15   3.5     False
# 2  Beltrano     18   9.3      True

# %%
dados.dtypes
tipos_de_dados = pd.DataFrame(dados.dtypes, columns = ['Tipos de Dados'])

# %%
tipos_de_dados.columns.name = 'Variáveis'

# %%
tipos_de_dados
# Out:
# Variáveis Tipos de Dados
# Nome              object
# Idade              int64
# Nota             float64
# Situação            bool

# %%
print(f'A base de dados possui {dados.shape[0]} registros (alunos) e {dados.shape[1]} variáveis (nota,nome..)')
# Out:
# A base de dados possui 3 registros (alunos) e 4 variáveis (nota,nome..)

# %% [markdown]
# ## Criação de um DataFrame

# %%
import pandas as pd
df1 = pd.DataFrame({'A': {'X': 1}, 'B': {'X': 2}})
df2 = pd.DataFrame({'C': {'X': 3}, 'D': {'X': 4}})

pd.concat([df1, df2])
# Out:
#      A    B    C    D
# X  1.0  2.0  NaN  NaN
# X  NaN  NaN  3.0  4.0

# %%
dados = [('A', 'B'), ('C', 'D')]
df = pd.DataFrame(dados, columns = ['L1', 'L2'],  index = ['C1', 'C2'])
df
# Out:
#    L1 L2
# C1  A  B
# C2  C  D

# %%
dados = [[1, 2, 3], [4, 5, 6]]
index = 'X,Y'.split(',')

columns = list('CBA')[::-1]
df = pd.DataFrame(dados, index, columns)
df
# Out:
#    A  B  C
# X  1  2  3
# Y  4  5  6

# %%
help(.split())
# Out:
#   Input In [15]
#     help(.split())
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Determinando seleções

# %%
import pandas as pd

numeros = [i for i in range(11)]
letras = [chr(i + 65) for i in range(11)]
nome_coluna = ['N']

df = pd.DataFrame(data = numeros, index = letras, columns = nome_coluna)
df
# Out:
#     N
# A   0
# B   1
# C   2
# D   3
# E   4
# F   5
# G   6
# H   7
# I   8
# J   9
# K  10

# %%
selecao = df['N'].isin([i for i in range(11) if i % 2 == 0])
df = df[selecao]
df
# Out:
#     N
# A   0
# C   2
# E   4
# G   6
# I   8
# K  10

# %% [markdown]
# ## Organizando DataFrame
# Transforme df_A em df_B

# %%
import pandas as pd
df_A = [['Ary','M',21],['Catia','F',19],['Carlos','M',50],['Beto','M',29],['Bruna','F',31],['Ana','F',42]]
df_A = pd.DataFrame(data=df_A,columns=['Nome','Sexo','Idade'],index=[0,1,2,3,4,5])
df_A
# Out:
#      Nome Sexo  Idade
# 0     Ary    M     21
# 1   Catia    F     19
# 2  Carlos    M     50
# 3    Beto    M     29
# 4   Bruna    F     31
# 5     Ana    F     42

# %%
df_B = df_A.sort_values(by=['Sexo','Nome'],axis=0)
df_B
# Out:
#      Nome Sexo  Idade
# 5     Ana    F     42
# 4   Bruna    F     31
# 1   Catia    F     19
# 0     Ary    M     21
# 3    Beto    M     29
# 2  Carlos    M     50

# %%
#Seleção de DataFrames
import pandas as pd
alunos = pd.DataFrame({'Nome': ['Ary', 'Cátia', 'Denis', 'Beto', 'Bruna', 'Dara', 'Carlos', 'Alice'], 
                        'Sexo': ['M', 'F', 'M', 'M', 'F', 'F', 'M', 'F'], 
                        'Idade': [15, 27, 56, 32, 42, 21, 19, 35], 
                        'Notas': [7.5, 2.5, 5.0, 10, 8.2, 7, 6, 5.6], 
                        'Aprovado': [True, False, False, True, True, True, False, False]}, 
                        columns = ['Nome', 'Idade', 'Sexo', 'Notas', 'Aprovado'])
alunos
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 0     Ary     15    M    7.5      True
# 1   Cátia     27    F    2.5     False
# 2   Denis     56    M    5.0     False
# 3    Beto     32    M   10.0      True
# 4   Bruna     42    F    8.2      True
# 5    Dara     21    F    7.0      True
# 6  Carlos     19    M    6.0     False
# 7   Alice     35    F    5.6     False

# %%
#Alunos aprovados
selecao = alunos['Aprovado'] == True
n1 = alunos[selecao]
n1
# Out:
#     Nome  Idade Sexo  Notas  Aprovado
# 0    Ary     15    M    7.5      True
# 3   Beto     32    M   10.0      True
# 4  Bruna     42    F    8.2      True
# 5   Dara     21    F    7.0      True

# %%
#Alunas F Aprovadas
selecao = (alunos['Aprovado'] == True) & (alunos['Sexo'] == 'F')
n2 = alunos[selecao]
n2
# Out:
#     Nome  Idade Sexo  Notas  Aprovado
# 4  Bruna     42    F    8.2      True
# 5   Dara     21    F    7.0      True

# %%
#Entre 10 e 20 anos ou maior igual a 40
selecao = ((alunos['Idade'] > 10) & (alunos['Idade'] < 20)) | (alunos['Idade'] >= 40)
n3 = alunos[selecao]
n3
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 0     Ary     15    M    7.5      True
# 2   Denis     56    M    5.0     False
# 4   Bruna     42    F    8.2      True
# 6  Carlos     19    M    6.0     False

# %% [markdown]
# ## Selecionando DataFrames
# Crie um DataFrame somente com os alunos reprovados e mantenha neste DataFrame apenas as colunas Nome, Sexo e Idade nesta ordem.

# %%
import pandas as pd
alunos = pd.DataFrame({'Nome': ['Ary', 'Cátia', 'Denis', 'Beto', 'Bruna', 'Dara', 'Carlos', 'Alice'], 
                        'Sexo': ['M', 'F', 'M', 'M', 'F', 'F', 'M', 'F'], 
                        'Idade': [15, 27, 56, 32, 42, 21, 19, 35], 
                        'Notas': [7.5, 2.5, 5.0, 10, 8.2, 7, 6, 5.6], 
                        'Aprovado': [True, False, False, True, True, True, False, False]}, 
                        columns = ['Nome', 'Idade', 'Sexo', 'Notas', 'Aprovado'])
alunos
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 0     Ary     15    M    7.5      True
# 1   Cátia     27    F    2.5     False
# 2   Denis     56    M    5.0     False
# 3    Beto     32    M   10.0      True
# 4   Bruna     42    F    8.2      True
# 5    Dara     21    F    7.0      True
# 6  Carlos     19    M    6.0     False
# 7   Alice     35    F    5.6     False

# %%
selecao = alunos['Aprovado'] == False
selecao
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4    False
# 5    False
# 6     True
# 7     True
# Name: Aprovado, dtype: bool

# %%
reprovados = alunos[selecao].loc[:,['Nome','Sexo','Idade']]
reprovados
# Out:
#      Nome Sexo  Idade
# 1   Cátia    F     27
# 2   Denis    M     56
# 6  Carlos    M     19
# 7   Alice    F     35

# %%
reprovados = alunos[selecao].iloc[:,[0,2,1]]
reprovados
# Out:
#      Nome Sexo  Idade
# 1   Cátia    F     27
# 2   Denis    M     56
# 6  Carlos    M     19
# 7   Alice    F     35

# %%
reprovados = alunos.loc[selecao,['Nome','Sexo','Idade']]
reprovados
# Out:
#      Nome Sexo  Idade
# 1   Cátia    F     27
# 2   Denis    M     56
# 6  Carlos    M     19
# 7   Alice    F     35

# %%
reprovados = alunos[selecao][['Nome','Sexo','Idade']]
reprovados
# Out:
#      Nome Sexo  Idade
# 1   Cátia    F     27
# 2   Denis    M     56
# 6  Carlos    M     19
# 7   Alice    F     35

# %%
reprovados = alunos[['Nome','Sexo','Idade']][selecao]
reprovados
# Out:
#      Nome Sexo  Idade
# 1   Cátia    F     27
# 2   Denis    M     56
# 6  Carlos    M     19
# 7   Alice    F     35

# %% [markdown]
# Crie uma visualização com os tres alunos mais novos.

# %%
alunos.sort_values(by = 'Idade', inplace=True)
alunos.iloc[:3,:]
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 0     Ary     15    M    7.5      True
# 6  Carlos     19    M    6.0     False
# 5    Dara     21    F    7.0      True

# %% [markdown]
# Revisando processo 5

# %%
import pandas as pd

# %%
imoveis = pd.DataFrame([['Apartamento', None, 970, 68], 
                        ['Apartamento', 2000, 878, 112], 
                        ['Casa', 5000, None, 500], 
                        ['Apartamento', None, 1010, 170], 
                        ['Apartamento', 1500, 850, None], 
                        ['Casa', None, None, None], 
                        ['Apartamento', 2000, 878, None], 
                        ['Apartamento', 1550, None, 228], 
                        ['Apartamento', 2500, 880, 195]], 
                        columns = ['Tipo', 'Valor', 'Condominio', 'IPTU'])
imoveis
# Out:
#           Tipo   Valor  Condominio   IPTU
# 0  Apartamento     NaN       970.0   68.0
# 1  Apartamento  2000.0       878.0  112.0
# 2         Casa  5000.0         NaN  500.0
# 3  Apartamento     NaN      1010.0  170.0
# 4  Apartamento  1500.0       850.0    NaN
# 5         Casa     NaN         NaN    NaN
# 6  Apartamento  2000.0       878.0    NaN
# 7  Apartamento  1550.0         NaN  228.0
# 8  Apartamento  2500.0       880.0  195.0

# %%
imoveis.dropna(subset=['Valor'],inplace=True)
imoveis
# Out:
#           Tipo   Valor  Condominio   IPTU
# 1  Apartamento  2000.0       878.0  112.0
# 2         Casa  5000.0         NaN  500.0
# 4  Apartamento  1500.0       850.0    NaN
# 6  Apartamento  2000.0       878.0    NaN
# 7  Apartamento  1550.0         NaN  228.0
# 8  Apartamento  2500.0       880.0  195.0

# %%
selecao = (imoveis['Tipo'] == 'Apartamento') & (imoveis['Condominio'].isnull())
imoveis = imoveis[~selecao]
imoveis.shape[0]
imoveis
# Out:
#           Tipo   Valor  Condominio   IPTU
# 1  Apartamento  2000.0       878.0  112.0
# 2         Casa  5000.0         NaN  500.0
# 4  Apartamento  1500.0       850.0    NaN
# 6  Apartamento  2000.0       878.0    NaN
# 8  Apartamento  2500.0       880.0  195.0

# %%
imoveis.fillna({'Condominio' : 0, 'IPTU' : 0},inplace=True)
imoveis
# Out:
#           Tipo   Valor  Condominio   IPTU
# 1  Apartamento  2000.0       878.0  112.0
# 2         Casa  5000.0         0.0  500.0
# 4  Apartamento  1500.0       850.0    0.0
# 6  Apartamento  2000.0       878.0    0.0
# 8  Apartamento  2500.0       880.0  195.0

# %%
imoveis.index = range(0,imoveis.shape[0])
imoveis
# Out:
#           Tipo   Valor  Condominio   IPTU
# 0  Apartamento  2000.0       878.0  112.0
# 1         Casa  5000.0         0.0  500.0
# 2  Apartamento  1500.0       850.0    0.0
# 3  Apartamento  2000.0       878.0    0.0
# 4  Apartamento  2500.0       880.0  195.0

# %% [markdown]
# ### Preenchendo dados Faltantes

# %%
import pandas as pd
atletas = pd.DataFrame([['Marcos', 9.62], ['Pedro', None], ['João', 9.69], 
                        ['Beto', 9.72], ['Sandro', None], ['Denis', 9.69], 
                        ['Ary', None], ['Carlos', 9.74]], 
                        columns = ['Corredor', 'Melhor Tempo'])
atletas
# Out:
#   Corredor  Melhor Tempo
# 0   Marcos          9.62
# 1    Pedro           NaN
# 2     João          9.69
# 3     Beto          9.72
# 4   Sandro           NaN
# 5    Denis          9.69
# 6      Ary           NaN
# 7   Carlos          9.74

# %%
atletas.fillna(value = atletas['Melhor Tempo'].mean(),inplace=True)
atletas
# Out:
#   Corredor  Melhor Tempo
# 0   Marcos         9.620
# 1    Pedro         9.692
# 2     João         9.690
# 3     Beto         9.720
# 4   Sandro         9.692
# 5    Denis         9.690
# 6      Ary         9.692
# 7   Carlos         9.740

# %% [markdown]
# Criação de Váriaveis

# %%
import pandas as pd
alunos = pd.DataFrame({'Nome': ['Ary', 'Cátia', 'Denis', 'Beto', 'Bruna', 'Dara', 'Carlos', 'Alice'], 
                        'Sexo': ['M', 'F', 'M', 'M', 'F', 'F', 'M', 'F'], 
                        'Idade': [15, 27, 56, 32, 42, 21, 19, 35], 
                        'Notas': [7.5, 2.5, 5.0, 10, 8.2, 7, 6, 5.6]}, 
                        columns = ['Nome', 'Idade', 'Sexo', 'Notas'])
alunos
# Out:
#      Nome  Idade Sexo  Notas
# 0     Ary     15    M    7.5
# 1   Cátia     27    F    2.5
# 2   Denis     56    M    5.0
# 3    Beto     32    M   10.0
# 4   Bruna     42    F    8.2
# 5    Dara     21    F    7.0
# 6  Carlos     19    M    6.0
# 7   Alice     35    F    5.6

# %%
alunos['Notas-Média(Notas)'] = alunos['Notas'] - alunos['Notas'].mean()

# %%
alunos['Notas-Média(Notas)'] = alunos['Notas'].apply(lambda x: x - alunos['Notas'].mean())

# %%
alunos['Faixa Etária'] = alunos['Idade'].apply(lambda x: 'Menor q 20 anos' if (x<20) else 'Entre 20 e 40 anos' if (x >= 20 and x <= 40) else 'Maior q 40 anos')
alunos
# Out:
#      Nome  Idade Sexo  Notas  Notas-Média(Notas)        Faixa Etária
# 0     Ary     15    M    7.5               1.025     Menor q 20 anos
# 1   Cátia     27    F    2.5              -3.975  Entre 20 e 40 anos
# 2   Denis     56    M    5.0              -1.475     Maior q 40 anos
# 3    Beto     32    M   10.0               3.525  Entre 20 e 40 anos
# 4   Bruna     42    F    8.2               1.725     Maior q 40 anos
# 5    Dara     21    F    7.0               0.525  Entre 20 e 40 anos
# 6  Carlos     19    M    6.0              -0.475     Menor q 20 anos
# 7   Alice     35    F    5.6              -0.875  Entre 20 e 40 anos

# %% [markdown]
#     Faces   m1  m2  m3  m4  m5
# C   Coroa   freqM1  ..  ..  ..
# c   cara    freqM2  ..  ..  ..
# Monte o DataFrame acima, para testarmos quais moedas são viciadas.

# %%
m1 = 'CCcCCccCCCccCcCccCcCcCCCcCCcccCCcCcCcCcccCCcCcccCc'
m2 = 'CCCCCccCccCcCCCCccCccccCccCccCCcCccCcCcCCcCccCccCc'
m3 = 'CccCCccCcCCCCCCCCCCcccCccCCCCCCccCCCcccCCCcCCcccCC'
m4 = 'cCCccCCccCCccCCccccCcCcCcCcCcCcCCCCccccCCCcCCcCCCC'
m5 = 'CCCcCcCcCcCCCcCCcCcCCccCcCCcccCccCCcCcCcCcCcccccCc'

# %%
df = pd.DataFrame([['Coroa', 'fM1', 'fM2', 'fM3', 'fM4', 'fM5'], ['Cara', 'fm1', 'fm2', 'fm3', 'fm4', 'fm5']], columns=['Faces','m1', 'm2', 'm3', 'm4', 'm5'], index=['C','c'])
df
# Out:
#    Faces   m1   m2   m3   m4   m5
# C  Coroa  fM1  fM2  fM3  fM4  fM5
# c   Cara  fm1  fm2  fm3  fm4  fm5

# %%
df['m1'] = pd.Series(list(m1)).value_counts()
df
# Out:
#    Faces  m1   m2   m3   m4   m5
# C  Coroa  25  fM2  fM3  fM4  fM5
# c   Cara  25  fm2  fm3  fm4  fm5

# %%
pd.Series(list(m2)).value_counts()
# Out:
# c    26
# C    24
# dtype: int64

# %%
df['m3'] = pd.Series(list(m3)).value_counts()
df['m4'] = pd.Series(list(m4)).value_counts()
df['m5'] = pd.Series(list(m5)).value_counts()

# %%
df
# Out:
#    Faces  m1  m2  m3  m4  m5
# C  Coroa  25  24  31  27  25
# c   Cara  25  26  19  23  25

# %%
eventos = {'m1' : list(m1), 'm2' : list(m2), 'm3' : list(m3), 'm4' : list(m4), 'm5' : list(m5)}
moedas = pd.DataFrame(eventos)
df = pd.DataFrame(data= ['Cara','Coroa'], index=['c','C'], columns=['Faces'])
df
# Out:
#    Faces
# c   Cara
# C  Coroa

# %%
for item in moedas:
    df = pd.concat([df, moedas[item].value_counts()], axis=1)
df
# Out:
#    Faces  m1  m2  m3  m4  m5
# c   Cara  25  26  19  23  25
# C  Coroa  25  24  31  27  25

# %% [markdown]
# Agrupamentos em DataFrame. groupby(). Obtenha um DataFrame com as notas médias dos alunos, com 2 casas decimais, segundo o sexo

# %%
import pandas as pd
alunos = pd.DataFrame({'Nome': ['Ary', 'Cátia', 'Denis', 'Beto', 'Bruna', 'Dara', 'Carlos', 'Alice'], 
                        'Sexo': ['M', 'F', 'M', 'M', 'F', 'F', 'M', 'F'], 
                        'Idade': [15, 27, 56, 32, 42, 21, 19, 35], 
                        'Notas': [7.5, 2.5, 5.0, 10, 8.2, 7, 6, 5.6], 
                        'Aprovado': [True, False, False, True, True, True, False, False]}, 
                        columns = ['Nome', 'Idade', 'Sexo', 'Notas', 'Aprovado'])

alunos
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 0     Ary     15    M    7.5      True
# 1   Cátia     27    F    2.5     False
# 2   Denis     56    M    5.0     False
# 3    Beto     32    M   10.0      True
# 4   Bruna     42    F    8.2      True
# 5    Dara     21    F    7.0      True
# 6  Carlos     19    M    6.0     False
# 7   Alice     35    F    5.6     False

# %%
grupo_sexo = alunos.groupby('Sexo')
sexo = pd.DataFrame(grupo_sexo['Notas'].mean().round(2))
sexo.columns = ['Notas Médias']
sexo
# Out:
#       Notas Médias
# Sexo
# F             5.82
# M             7.12

# %% [markdown]
# Criando DataFrame agrupado por produtos e exibindo análises estatísticas

# %%
import pandas as pd
precos = pd.DataFrame([['Feira', 'Cebola', 2.5], 
                        ['Mercado', 'Cebola', 1.99], 
                        ['Supermercado', 'Cebola', 1.69], 
                        ['Feira', 'Tomate', 4], 
                        ['Mercado', 'Tomate', 3.29], 
                        ['Supermercado', 'Tomate', 2.99], 
                        ['Feira', 'Batata', 4.2], 
                        ['Mercado', 'Batata', 3.99], 
                        ['Supermercado', 'Batata', 3.69]], 
                        columns = ['Local', 'Produto', 'Preço'])
precos
# Out:
#           Local Produto  Preço
# 0         Feira  Cebola   2.50
# 1       Mercado  Cebola   1.99
# 2  Supermercado  Cebola   1.69
# 3         Feira  Tomate   4.00
# 4       Mercado  Tomate   3.29
# 5  Supermercado  Tomate   2.99
# 6         Feira  Batata   4.20
# 7       Mercado  Batata   3.99
# 8  Supermercado  Batata   3.69

# %%
produtos = precos.groupby('Produto')
produtos.describe().round(2)
# Out:
#         Preço
#         count  mean   std   min   25%   50%   75%  max
# Produto
# Batata    3.0  3.96  0.26  3.69  3.84  3.99  4.10  4.2
# Cebola    3.0  2.06  0.41  1.69  1.84  1.99  2.24  2.5
# Tomate    3.0  3.43  0.52  2.99  3.14  3.29  3.64  4.0

# %%
estatisticas = ['mean', 'std', 'min', 'max']
nomes = {'mean':'Média', 'std':'Desvio Padrão', 'min':'Mínimo', 'max':'Máximo'}
produtos['Preço'].aggregate(estatisticas).rename(columns=nomes).round(2)
# Out:
#          Média  Desvio Padrão  Mínimo  Máximo
# Produto
# Batata    3.96           0.26    3.69     4.2
# Cebola    2.06           0.41    1.69     2.5
# Tomate    3.43           0.52    2.99     4.0

# %% [markdown]
# Obtenha os quartis e IIQ do df (Valor do m2) abaixo

# %%
import pandas as pd
import matplotlib as plt

# %%
df = pd.read_csv('dados/aluguel_amostra.csv', sep=';')
df.head()
# Out:
#           Tipo                    Bairro  Quartos  Vagas  Suites  Area  \
# 0  Apartamento  Recreio dos Bandeirantes        3      2       1   320
# 1  Apartamento                  Maracanã        2      0       0    59
# 2  Apartamento                    Leblon        3      2       1   147
# 3  Apartamento               São Conrado        3      3       3   270
# 4  Apartamento                    Tijuca        2      1       0    65
#
#      Valor  Condominio    IPTU  Valor m2 Tipo Agregado
# 0   3200.0      1319.0     0.0     10.00   Apartamento
# 1    800.0       725.0    47.0     13.56   Apartamento
# 2   7500.0      1000.0   381.0     51.02   Apartamento
# 3  14999.0      2800.0  1200.0     55.55   Apartamento
# 4   1200.0       640.0    97.0     18.46   Apartamento

# %%
Q1 = df['Valor m2'].quantile(0.25)
Q3 = df['Valor m2'].quantile(0.75)
IIQ = (Q3 - Q1).round(2)

# %%
print(f'Q1 -> {Q1} \nQ3 -> {Q3} \nIIQ -> {IIQ}')
# Out:
# Q1 -> 21.25
# Q3 -> 42.31
# IIQ -> 21.06

# %%
limite_inferior = (Q1 - 1.5*IIQ).round(2)
limite_superior = (Q3 + 1.5*IIQ).round(2)
print(f'limite inferior - {limite_inferior} \n limite superior - {limite_superior}')
# Out:
# limite inferior - -10.34
#  limite superior - 73.9

# %% [markdown]
# ## Construção de Gráfico em Pizza

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
plt.rc('figure', figsize = (15,7))
dados = pd.read_csv('dados/aluguel_residencial_sem_outliers.csv', sep=';')
dados.head()
# Out:
#           Tipo               Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0  Apartamento               Centro        1      0       0    15   800.0
# 1  Apartamento         Higienópolis        1      0       0    48   800.0
# 2  Apartamento             Cachambi        2      0       0    50  1300.0
# 3  Apartamento               Grajaú        2      1       0    70  1500.0
# 4  Apartamento  Lins de Vasconcelos        3      1       1    90  1500.0
#
#    Condominio  IPTU  Valor m2 Tipo Agregado
# 0       390.0  20.0     53.33   Apartamento
# 1       230.0   0.0     16.67   Apartamento
# 2       301.0  17.0     26.00   Apartamento
# 3       642.0  74.0     21.43   Apartamento
# 4       455.0  14.0     16.67   Apartamento

# %%
area = plt.figure()

# %%
g1 = area.add_subplot(2,2,1)
g2 = area.add_subplot(2,2,2)
grupo1 = dados.groupby('Tipo Agregado')['Valor']
label = grupo1.count().index
valores = grupo1.count().values
g1.pie(valores, labels=label, autopct='%1.1f%%')
g1.set_title('Total de Imóveis por tipo Agregado')
grupo2  = dados.groupby('Tipo')['Valor']
label = grupo2.count().index
valores = grupo2.count().index
valores = grupo2.count().values
g2.pie(valores, labels=label, autopct = '%.1f%%', explode= (.1, .1, .1, .1, .1))
g2.set_title('Total de Imóveis por Tipo')
# Out:
# Text(0.5, 1.0, 'Total de Imóveis por Tipo')

# %%
area
